# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 

excel_file_path= 'Ascites Hepatic.xlsx'

# %%
xls = pd.ExcelFile(excel_file_path)

sheet_names = xls.sheet_names

print(f'Number of tabs (worksheets): {len(sheet_names)}')
print(f'Tab names: {sheet_names}')
# Out:
# Number of tabs (worksheets): 4
# Tab names: ['part1', 'part2', 'part3', 'part4']

# %%
sheet1 = pd.read_excel(excel_file_path, sheet_name='part1')
sheet1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  32 non-null     object
#  1   Unnamed: 1  25 non-null     object
#  2   Unnamed: 2  25 non-null     object
#  3   Unnamed: 3  25 non-null     object
#  4   Unnamed: 4  25 non-null     object
#  5   Unnamed: 5  24 non-null     object
# dtypes: object(6)
# memory usage: 1.6+ KB

# %%
sheet1.head(100)
# Out:
#                                 Unnamed: 0   Unnamed: 1 Unnamed: 2  \
# 0                              18-51 years  52-72 years  73+ years
# 1                          Number of stays        225.9      383.2
# 2   Rate of stays (per 100,000 population)        155.4      503.1
# 3              Utilization characteristics          NaN        NaN
# 4                    Cost per stay, mean $           11       14.6
# 5                Length of stay, mean days          5.5        6.0
# 6             Died during hospital stay, %          1.5        3.5
# 7                  Patient characteristics          NaN        NaN
# 8                                   Sex, %          NaN        NaN
# 9                                     Male         54.7       66.5
# 10                                  Female         45.3       33.5
# 11                       Race/ethnicity, %          NaN        NaN
# 12                                   White         67.1       54.5
# ...

# %%
transposed_sheet1 = sheet1.transpose()
transposed_sheet1.head(50)
# Out:
#                               0                1   \
# Unnamed: 0           18-51 years  Number of stays
# Unnamed: 1           52-72 years            225.9
# Unnamed: 2             73+ years            383.2
# Unnamed: 3  All adults 18+ years             27.8
# Unnamed: 4  All adults 18+ years            636.9
# Unnamed: 5                   NaN       29,115,100
#
#                                                 2   \
# Unnamed: 0  Rate of stays (per 100,000 population)
# Unnamed: 1                                   155.4
# Unnamed: 2                                   503.1
# Unnamed: 3                                   117.1
# Unnamed: 4                                   259.7
# Unnamed: 5                                11,870.5
#
#                                      3                      4   \
# Unnamed: 0  Utilization characteristics  Cost per stay, mean $
# Unnamed: 1                          NaN                     11
# ...

# %%
transposed_sheet1 = transposed_sheet1.reset_index(drop = True)

# %%
transposed_sheet1.head()
# Out:
#                      0                1   \
# 0           18-51 years  Number of stays
# 1           52-72 years            225.9
# 2             73+ years            383.2
# 3  All adults 18+ years             27.8
# 4  All adults 18+ years            636.9
#
#                                        2                            3   \
# 0  Rate of stays (per 100,000 population)  Utilization characteristics
# 1                                   155.4                          NaN
# 2                                   503.1                          NaN
# 3                                   117.1                          NaN
# 4                                   259.7                          NaN
#
#                       4                          5   \
# 0  Cost per stay, mean $  Length of stay, mean days
# 1                     11                        5.5
# 2                   14.6                        6.0
# 3                   14.5                        6.1
# ...

# %%
# Out:
#                           0                1   \
# count                      5                6
# unique                     4                6
# top     All adults 18+ years  Number of stays
# freq                       2                1
#
#                                             2                            3   \
# count                                        6                            1
# unique                                       6                            1
# top     Rate of stays (per 100,000 population)  Utilization characteristics
# freq                                         1                            1
#
#                            4                          5   \
# count                       6                          6
# unique                      6                          6
# top     Cost per stay, mean $  Length of stay, mean days
# freq                        1                          1
#
# ...

# %%
sheet2 = pd.read_excel(excel_file_path, sheet_name='part2')

# %%
sheet2.head(50)
# Out:
#                                  Unnamed: 0   Unnamed: 1 Unnamed: 2  \
# 0                               18-51 years  52-72 years  73+ years
# 1                              Diagnosis, %          NaN        NaN
# 2         Hepatitis C (principal diagnosis)          3.7        6.3
# 3                               Hepatitis B          3.4        3.2
# 4                                       HIV          7.1        6.1
# 5             Alcoholic liver disease (ALD)          9.1       13.6
# 6                              Liver cancer          1.0        6.2
# 7                    Cirrhosis of the liver          9.7       23.8
# 8                                   Ascites          7.2       14.7
# 9                         Upper GI bleeding          4.5        7.1
# 10                      Any mental disorder         78.4       69.7
# 11                       Any nonalcohol SUD         53.5       24.9
# 12  Any alcohol-related diagnosis (not ALD)         26.8       26.9
# ...

# %%
transposed_sheet2 = sheet2.transpose()

# %%
transposed_sheet2.head(50)
# Out:
#                               0             1   \
# Unnamed: 0           18-51 years  Diagnosis, %
# Unnamed: 1           52-72 years           NaN
# Unnamed: 2             73+ years           NaN
# Unnamed: 3  All adults 18+ years           NaN
# Unnamed: 4  All adults 18+ years           NaN
# Unnamed: 5                   NaN           NaN
#
#                                            2            3    4   \
# Unnamed: 0  Hepatitis C (principal diagnosis)  Hepatitis B  HIV
# Unnamed: 1                                3.7          3.4  7.1
# Unnamed: 2                                6.3          3.2  6.1
# Unnamed: 3                                5.0          2.4  1.3
# Unnamed: 4                                5.3          3.3  6.2
# Unnamed: 5                                  -          0.2  0.6
#
#                                        5             6   \
# Unnamed: 0  Alcoholic liver disease (ALD)  Liver cancer
# Unnamed: 1                            9.1           1.0
# ...

# %%
sheet2.iloc[0:12]
# Out:
#                            Unnamed: 0   Unnamed: 1 Unnamed: 2  \
# 0                         18-51 years  52-72 years  73+ years
# 1                        Diagnosis, %          NaN        NaN
# 2   Hepatitis C (principal diagnosis)          3.7        6.3
# 3                         Hepatitis B          3.4        3.2
# 4                                 HIV          7.1        6.1
# 5       Alcoholic liver disease (ALD)          9.1       13.6
# 6                        Liver cancer          1.0        6.2
# 7              Cirrhosis of the liver          9.7       23.8
# 8                             Ascites          7.2       14.7
# 9                   Upper GI bleeding          4.5        7.1
# 10                Any mental disorder         78.4       69.7
# 11                 Any nonalcohol SUD         53.5       24.9
#
#               Unnamed: 3            Unnamed: 4 Unnamed: 5
# 0   All adults 18+ years  All adults 18+ years        NaN
# ...

# %%
sheet3 = pd.read_excel(excel_file_path, sheet_name='part3')
sheet4 = pd.read_excel(excel_file_path, sheet_name='part4')

# %%
sheet3.head(50)
# Out:
#                                       Unnamed: 0  \
# 0   Hepatitis C without hepatitis B, HIV, or ALD
# 1                                Number of stays
# 2            Percentage of all baby boomer stays
# 3         Rate of stays (per 100,000 population)
# 4                    Utilization characteristics
# 5                          Cost per stay, mean $
# 6                      Length of stay, mean days
# 7                   Died during hospital stay, %
# 8                        Patient characteristics
# 9                                         Sex, %
# 10                                          Male
# 11                                        Female
# 12                             Race/ethnicity, %
# 13                                         White
# 14                                         Black
# 15                                      Hispanic
# 16                                         Other
# 17                     Expected primary payer, %
# ...

# %%
sheet4.head(50)
# Out:
#              iagnosis, procedure, or comorbidity  \
# 0   Hepatitis C without hepatitis B, HIV, or ALD
# 1                                   Diagnosis, %
# 2              Hepatitis C (principal diagnosis)
# 3                                    Hepatitis B
# 4                                            HIV
# 5                  Alcoholic liver disease (ALD)
# 6                                   Liver cancer
# 7                         Cirrhosis of the liver
# 8                                        Ascites
# 9                              Upper GI bleeding
# 10                           Any mental disorder
# 11                            Any nonalcohol SUD
# 12       Any alcohol-related diagnosis (not ALD)
# 13                                  Procedure, %
# 14                        Abdominal paracentesis
# 15                            Upper GI endoscopy
# 16                                Comorbidity, %
# 17                                  Hypertension
# ...
